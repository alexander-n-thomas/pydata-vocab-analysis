# %% [markdown]
# # Vocabulary Analysis Workshop
#
# ## Tokenization
#
# The first thing we will do is split the job description text into tokens.
# A token is an element (word, character, symbol) of a string. For example, the string "Cows eat grass" can be tokenized into words or characters:
# - "Cows", "eat", "grass"
# - 'C', 'o', 'w', 's', ' ', 'e', 'a', 't', ' ', 'g', 'r', 'a', 's', 's'
#
# (Tokenization [wikipedia](https://en.wikipedia.org/wiki/Tokenization_(lexical_analysis))
#
# Tokenization is a text segmentation process that reduces a string into a list of the tokens (elements) that make up the string. In natural language processing (NLP) it is generally used to refer the process of taking text and producing a list of words. Tokens are also used to refer to the characters of a string.
#
# Tokenization is often the first process applied to a piece of text, and because of this it heavily affect downstream processes. This can be complicated because there isn't necessarily a "correct" way to tokenize. Depending on language, kind of document, and downstream processes tokenization can be vastly different.

# %%
from __future__ import division, print_function

# %matplotlib inline

import nltk
import pandas as pd
import pickle

from vocab_analysis import *

import answers

# %%
jobs_df = pd.read_csv('data/job_descriptions.tsv', sep='\t', encoding='UTF-8', index_col=0)

# %%
jobs_df
# Out:
#                                             description experience  \
# id
# 0     THE COMPANY    Employer is a midstream service...         5+
# 1     ICR Staffing is now accepting resumes for Indu...        2-5
# 2     This is a great position for the right person....       none
# 3     A large multi-specialty health center is expan...       none
# 4     JOB PURPOSE:    The Account Director is respon...         5+
# 5     At Cottage Health System, our facilities are s...         5+
# 6     *E Learning Instructional Designer with at lea...         5+
# 7     Sales and Service Representative    SAF-Hollan...         5+
# 8     SAF-Holland, Inc. is currently seeking an Inte...        2-5
# 9     Immediate opening for full time staffing coord...       none
# 10    WE ARE CHANGING LIVES! We invite you to join u...       none
# 11    1.  Associate level resource with 2-3 years In...        2-5
# 12    A Leader in the Field of Photonics  Founded in...       none
# 13    A Leader in the Field of Photonics  Founded in...       none
# 14    JOB SUMMARY: Facilitate the definition, idea g...        2-5
# 15    Growing company in Celina is looking for an Of...       none
# 16    *Position: Industrial Sales Engineer*  Delta T...        2-5
# 17    *Join the Club!* *Your Local Hermantown, MN Sa...       none
# 18    *Join the Club!*  Today, we are 625 clubs stro...       none
# 19    New York Police Department    *Take The NYPD P...       none
# 20    REQ#DT0536 Front-End Web Development & Graphic...        2-5
# 21    EXPERIENCE ONLY CLICK TO REPLY>>  GREAT OPPORT...         5+
# 22    EXPERIENCE ONLY APPLY OR CLICK  • Status: Dire...        1-2
# 23    There are exciting career opportunities for br...        2-5
# 24    CTM Media Group has built its success and repu...       none
# 25    Beeby Clark+Meyler has strong roots in interac...        2-5
# 26    Inside Technical Sales    Do You Have The Tech...        2-5
# 27    Qualifications:  Seeking a part time Rehabilit...       none
# 28    ARE YOU a licensed P&C account manager in the ...        2-5
# 29    Drivers -   Class A CDL  Black Horse Carriers ...        2-5
# ...                                                 ...        ...
# 4345  ADVANCE YOUR CAREER WITH BURGER KING - QUICK S...       none
# 4346  Kids’ Gym Full Time Instructor:    Do you like...       none
# 4347  MAACO Collision Repair in Greenville, SC is lo...        2-5
# 4348  CLASS A CDL DRIVERS: 48 CPM WOULD YOU RUN FOR ...       none
# 4349  *DEPARTMENT:* Supply Chain Management  *REPORT...        2-5
# 4350  Spa Coordinator                               ...       none
# 4351  Orthodentrix is looking for an entrepreneurial...       none
# 4352  Local community bank is seeking a qualified in...         5+
# 4353  OutSell: OutSell was founded in 1996 with the ...       none
# 4354  We are seeking an enthusiastic candidate to fi...       none
# 4355  AAA East Central is looking for someone to del...       none
# 4356  Local Allstate agency is looking for a motivat...       none
# 4357  Gourmet to go Markets is looking for Attendant...       none
# 4358  Come join the elite Shorrock team who has rece...       none
# 4359  We pride ourselves in our high quality pizza a...       none
# 4360  Community Care, Inc.  is currently seeking a P...       none
# 4361  We are looking for Real Sports Fans who would ...       none
# 4362  SiteJabber (www.example.com) is the leading co...        1-2
# 4363  AOTMP is seeking an experienced, high energy, ...         5+
# 4364  The Insurance Account Manager position is the ...        2-5
# 4365  Experience - 1-3 years in Food & Hospitality I...        1-2
# 4366  Lead a group of elderly during the lunch hour ...       none
# 4367  This is an amazing opportunity for an experien...         5+
# 4368  The Receptionist/Office assistant will provide...         5+
# 4369  This position is responsible for correcting, p...       none
# 4370  m.pulse is currently seeking a Spa Receptionis...        1-2
# 4371  Responsibilities:  Design, develop and deliver...         5+
# 4372  ExamOne, a subsidiary of Quest Diagnostics, is...       none
# 4373  Entry level position, no prior work experience...       none
# 4374  Iron Sword Enterprises, LLC is seeking an expe...         5+
#
#              education  is_hourly  is_part_time  is_supervisor
# id
# 0                 none      False         False           True
# 1                 none      False         False          False
# 2                 none      False          True          False
# 3                 none      False         False          False
# 4     bs-degree-needed      False         False           True
# 5     associate-needed      False         False          False
# 6     ms-or-phd-needed      False         False          False
# 7     bs-degree-needed      False         False          False
# 8     bs-degree-needed      False         False          False
# 9                 none       True         False          False
# 10                none      False         False          False
# 11                none      False         False          False
# 12                none      False         False          False
# 13                none       True         False          False
# 14    bs-degree-needed      False         False          False
# 15                none       True         False          False
# 16    bs-degree-needed      False         False          False
# 17                none      False         False          False
# 18                none      False         False          False
# 19                none      False         False          False
# 20    bs-degree-needed      False         False          False
# 21    bs-degree-needed      False         False           True
# 22                none      False         False          False
# 23                none      False         False          False
# 24                none      False         False          False
# 25    bs-degree-needed      False         False          False
# 26    associate-needed      False         False          False
# 27                none      False          True          False
# 28                none      False         False          False
# 29                none      False         False          False
# ...                ...        ...           ...            ...
# 4345              none      False         False           True
# 4346              none      False         False          False
# 4347              none       True         False          False
# 4348              none      False         False          False
# 4349  bs-degree-needed      False         False          False
# 4350              none      False         False          False
# 4351              none      False         False          False
# 4352              none      False         False          False
# 4353              none      False         False          False
# 4354              none      False         False          False
# 4355  bs-degree-needed      False         False          False
# 4356              none      False         False          False
# 4357              none      False         False          False
# 4358              none       True         False          False
# 4359              none       True          True          False
# 4360              none      False         False          False
# 4361              none      False         False          False
# 4362              none      False         False          False
# 4363  bs-degree-needed      False         False          False
# 4364              none      False         False          False
# 4365              none      False         False          False
# 4366              none      False         False          False
# 4367  bs-degree-needed      False         False           True
# 4368  associate-needed      False         False          False
# 4369              none      False         False          False
# 4370              none      False         False          False
# 4371  bs-degree-needed      False         False          False
# 4372              none      False         False          False
# 4373  bs-degree-needed      False         False          False
# 4374  bs-degree-needed      False         False          False
#
# [4375 rows x 6 columns]

# %%
len(jobs_df)
# Out:
# 4375

# %% [markdown]
# ### Exercise 1: Tokenization
#
# Tokenization in English is often implemented with heuristics or regular expressions. Regular expressions can be used in one of two ways: to identify boundaries, or to identify tokens. Here are some common regular expressions for tokenizing English.
#
# Here are some questions to consider when doing tokenization.
# - How do I want to treat punctuation?
#   - Should "word." tokenize to ["word", "."], ["word."], or ["word"])?
# - How do I want to treat contractions (e.g. should we)?
#   - Should we pre-treat contractions by expanding all instances in the text?
#     - "won't" to "will not" then tokenize to ["will", "not"]
#   - Should we keep contractions together? Or break them up?
#     - "won't" tokenizes to ["won't"] or ["won", "'", "t"]
#   - Are we dealing with a more formal version English, and contractions are rare?
# - How do we want to treat numbers?
#   - Should "A1" tokenize to ["A1"] or ["A", "1"]?
# - How do we treat hyphens?
#   - Should "State-of-the-art" tokenize to ["State-of-the-art"], ["State", "of", "the", "art"], or ["State", "-", "of", "-", "the", "-", "art"]
#
# Implement your tokenizer. When using regular expression based tokenizers, the common approaches are to either use the regular expression to identify tokens and extract all matches, or identify gaps and split the string. Use the example below to test out your tokenizer.

# %%
example_job_description = """
This is a description for a generic job.

The employee is expected have the following:
    1. an A1 certifcation (recent or renewed)
    2. experience in widget-widget interaction
    
She/he will be expected to be stand for 3-4 hours at a time.
She/he won't be expected to actually create widgets.

Full-time
Salary : $50,000/yr
"""

# %%
# def tokenize(job_description):
#     """
#     This function takes a job description and returns a list of tokens
#     Parameters
#     ----------
#     job_description : str
#         The text of the job description
#     Returns
#     ----------
#     list[str]
#         The list of tokens in the job description
#     """
#     raise NotImplementedError('Implement the tokenizer')

tokenize = answers.tokenize # uncomment this, and comment the above function to skip this exercise

# %%
tokenize(example_job_description)
# Out:
# ['This',
#  'is',
#  'a',
#  'description',
#  'for',
#  'a',
#  'generic',
#  'job',
#  '.',
#  'The',
#  'employee',
#  'is',
#  'expected',
#  'have',
#  'the',
#  'following',
#  ':',
#  '1',
#  '.',
#  'an',
#  'A1',
#  'certifcation',
#  '(',
#  'recent',
#  'or',
#  'renewed',
#  ')',
#  '2',
#  '.',
#  'experience',
#  'in',
#  'widget',
#  '-',
#  'widget',
#  'interaction',
#  'She',
#  '/',
#  'he',
#  'will',
#  'be',
#  'expected',
#  'to',
#  'be',
#  'stand',
#  'for',
#  '3',
#  '-',
#  '4',
#  'hours',
#  'at',
#  'a',
#  'time',
#  '.',
#  'She',
#  '/',
#  'he',
#  'won',
#  "'",
#  't',
#  'be',
#  'expected',
#  'to',
#  'actually',
#  'create',
#  'widgets',
#  '.',
#  'Full',
#  '-',
#  'time',
#  'Salary',
#  ':',
#  '$50,000',
#  '/',
#  'yr']

# %% [markdown]
# When you are happy with your tokenization, let's tokenize the descriptions, save our work, and move on to analysis using $\mbox{TF.IDF}$.

# %%
jobs_df['tokens'] = jobs_df['description'].apply(tokenize)

# %%
jobs_df.to_pickle('data/tokenized.pickle')

# %% [markdown]
# Let's also save our tokenization method

# %%
save_fun(tokenize, imports=['nltk'])

# %% [markdown]
# ### NEXT => [2. TF.IDF](2. TF.IDF.ipynb)
